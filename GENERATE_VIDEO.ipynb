# %%
# show images inline
# %matplotlib inline

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
import keras
# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time
import mmcv
# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf
# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu
from keras_retinanet.utils.visual import draw_caption1



def get_session():
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    return tf.Session(config=config)

# use this to change which GPU to use
gpu = 0

# set the modified tf session as backend in keras
setup_gpu(gpu)
# Out:
# Using TensorFlow backend.

# %%
# adjust this to point to your downloaded/trained model
# models can be downloaded here: https://github.com/fizyr/keras-retinanet/releases
model_path = os.path.join('/home/victor/keras-retinanet/', 'snapshots', 'resnet50_csv_49.h5')

# load retinanet model
model = models.load_model(model_path, backbone_name='resnet50')

# if the model is not converted to an inference model, use the line below
# see: https://github.com/fizyr/keras-retinanet#converting-a-training-model-to-inference-model
model = models.convert_model(model)

#print(model.summary())

# load label to names mapping for visualization purposes
#labels_to_names = {0: 'person', 1: 'cyclist', 2: 'Car', 3: 'motorcyclist', 4: 'tricyclist', 5: 'Bus', 6: 'wheelchairuser', 7: 'Truck', 8: 'Ambulance'}
labels_to_names = {0: 'Airplane'}
# Out:
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-22.627417, -11.313708,  22.627417,  11.313708],
#        [-28.50876 , -14.25438 ,  28.50876 ,  14.25438 ],
#        [-35.918785, -17.959393,  35.918785,  17.959393],
#        [-16.      , -16.      ,  16.      ,  16.      ],
#        [-20.158737, -20.158737,  20.158737,  20.158737],
#        [-25.398417, -25.398417,  25.398417,  25.398417],
#        [-11.313708, -22.627417,  11.313708,  22.627417],
#        [-14.25438 , -28.50876 ,  14.25438 ,  28.50876 ],
#        [-17.959393, -35.918785,  17.959393,  35.918785]], dtype=float32)> anchors
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32, numpy=
# array([[-45.254833, -22.627417,  45.254833,  22.627417],
#        [-57.01752 , -28.50876 ,  57.01752 ,  28.50876 ],
#        [-71.83757 , -35.918785,  71.83757 ,  35.918785],
#        [-32.      , -32.      ,  32.      ,  32.      ],
#        [-40.317474, -40.317474,  40.317474,  40.317474],
# ...

# %%
path='/home/victor/Frame/Airplane/720p - CARBONITE 2 video Mumbai airport - YouTube.webm' 
video = mmcv.VideoReader(path)

# %%
i=0
for image in video:
    # copy to draw on
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

# preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)

# process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)

# correct for image scale
    boxes /= scale

# visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
    # scores are sorted so we can break
        if score < 0.5:
            break
        
        color = label_color(label)
    
        b = box.astype(int)
        draw_box(draw, b, color=color,thickness=3)
    
        caption = "{} {:.3f}".format(labels_to_names[label], score)
        #print(caption)
        draw_caption1(draw, b, caption,size=1,thickness=1,R=255,G=255,B=0)
    #cv2.imwrite('/home/victor/keras-retinanet/result'+caption+'.jpg',draw1)
    

    save_img=cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)
    cv2.imwrite('/home/victor/Frame/cvt_frame/'+str(i).zfill(6)+'.jpg',save_img)
    i=i+1
# Out:
# processing time:  1.133596658706665
# processing time:  1.2388768196105957
# processing time:  1.2337522506713867
# processing time:  1.2276825904846191
# processing time:  1.2338778972625732
# processing time:  1.2360620498657227
# processing time:  1.2341465950012207
# processing time:  1.2242255210876465
# processing time:  1.2189428806304932
# processing time:  1.229280948638916
# processing time:  1.2269766330718994
# processing time:  1.219334602355957
# processing time:  1.2263360023498535
# processing time:  1.2182011604309082
# processing time:  1.2227067947387695
# processing time:  1.2229788303375244
# processing time:  1.2306585311889648
# processing time:  1.2184576988220215
# processing time:  1.2179200649261475
# processing time:  1.223093032836914
# processing time:  1.2269587516784668
# processing time:  1.2304456233978271
# processing time:  1.230302333831787
# processing time:  1.2315301895141602
# processing time:  1.2339613437652588
# ...

# %%
mmcv.frames2video('/home/victor/Frame/cvt_frame/', '/home/victor/Frame/video/airport2.mp4')
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 1335/1335, 130.5 task/s, elapsed: 10s, ETA:     0s
